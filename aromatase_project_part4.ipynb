# %% [markdown]
# <a href="https://colab.research.google.com/github/gowravmannem/Aromatase-Drug-Discovery/blob/main/aromatase_project_part4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 4: Comparing Regressors Model

# %% [markdown]
# ## Import Libraries

# %%
! pip install lazypredict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.7/dist-packages (0.2.9)
# Requirement already satisfied: pandas==1.0.5 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.5)
# Requirement already satisfied: scipy==1.5.4 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.5.4)
# Requirement already satisfied: tqdm==4.56.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (4.56.0)
# Requirement already satisfied: xgboost==1.1.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.1.1)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: numpy==1.19.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.19.1)
# Requirement already satisfied: PyYAML==5.3.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (5.3.1)
# Requirement already satisfied: lightgbm==2.3.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (2.3.1)
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.15.0)
# Requirement already satisfied: pytest==5.4.3 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (5.4.3)
# Requirement already satisfied: scikit-learn==0.23.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (0.23.1)
# Requirement already satisfied: joblib==1.0.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2022.1)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (4.12.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (1.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.3)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (0.13.1)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (8.13.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.4.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (0.2.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.23.1->lazypredict) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytest==5.4.3->lazypredict) (3.0.9)

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## Loading Data

# %%
aromatase_fp_df = pd.read_csv('aromatase_3class_pIC50_pubchem_fp.csv')

# %%
aromatase_lipinski = pd.read_csv('aromatase_3class_pIC50.csv')

# %%
# assigning X and Y values
aromatase_fp = aromatase_fp_df.drop('pIC50', axis=1)
aromatase_3des = aromatase_lipinski[["MW","NumHDonors","NumHAcceptors"]]
aromatase_X = pd.concat([aromatase_fp, aromatase_3des], axis=1).reindex(aromatase_fp.index)
aromatase_Y = aromatase_fp_df.pIC50

# %%
# Out:
# array([[  1.   ,   1.   ,   0.   , ..., 329.528,   2.   ,   2.   ],
#        [  1.   ,   1.   ,   0.   , ..., 315.501,   2.   ,   2.   ],
#        [  1.   ,   1.   ,   1.   , ..., 412.306,   0.   ,   3.   ],
#        ...,
#        [  1.   ,   1.   ,   1.   , ..., 384.439,   3.   ,   6.   ],
#        [  1.   ,   1.   ,   1.   , ..., 384.435,   3.   ,   5.   ],
#        [  1.   ,   1.   ,   1.   , ..., 383.451,   3.   ,   5.   ]])

# %% [markdown]
# ## Data pre-proccessing

# %%
# Removing low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
aromatase_X = selection.fit_transform(aromatase_X)
aromatase_X.shape
# Out:
# (2817, 155)

# %%
# Data splitting with 4:1 ratio
aromatase_X_train, aromatase_X_test, aromatase_Y_train, aromatase_Y_test = train_test_split(aromatase_X, aromatase_Y, test_size=0.2)

# %% [markdown]
# # Comparing Machine Learning Models

# %%
# building the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
aromatase_train, aromatase_test = clf.fit(aromatase_X_train, aromatase_X_test, aromatase_Y_train, aromatase_Y_test)
# Out:
# 100%|██████████| 42/42 [00:35<00:00,  1.19it/s]

# %%
# Performance table to many models on the training datset (80%)
aromatase_train
# Out:
#                                         Adjusted R-Squared  \
# Model
# HistGradientBoostingRegressor                         0.27
# LGBMRegressor                                         0.26
# RandomForestRegressor                                 0.25
# NuSVR                                                 0.23
# BaggingRegressor                                      0.20
# MLPRegressor                                          0.20
# SVR                                                   0.20
# GradientBoostingRegressor                             0.19
# XGBRegressor                                          0.18
# Ridge                                                 0.15
# RidgeCV                                               0.15
# BayesianRidge                                         0.14
# KNeighborsRegressor                                   0.14
# ElasticNetCV                                          0.13
# LassoCV                                               0.13
# PoissonRegressor                                      0.13
# LassoLarsIC                                           0.12
# HuberRegressor                                        0.11
# LinearSVR                                             0.10
# SGDRegressor                                          0.10
# GammaRegressor                                        0.08
# GeneralizedLinearRegressor                            0.08
# TweedieRegressor                                      0.08
# LassoLarsCV                                           0.07
# OrthogonalMatchingPursuitCV                           0.06
# OrthogonalMatchingPursuit                             0.06
# ExtraTreesRegressor                                   0.02
# AdaBoostRegressor                                    -0.01
# DecisionTreeRegressor                                -0.04
# ExtraTreeRegressor                                   -0.10
# LarsCV                                               -0.12
# PassiveAggressiveRegressor                           -0.21
# ElasticNet                                           -0.38
# Lasso                                                -0.38
# DummyRegressor                                       -0.38
# LassoLars                                            -0.38
# KernelRidge                                         -26.51
# GaussianProcessRegressor                          -9770.09
# Lars                                             -55631.81
# LinearRegression                  -21915713170742718464.00
# TransformedTargetRegressor        -21915713170742718464.00
# RANSACRegressor               -445531037026201561464832.00
#
#                                                  R-Squared            RMSE  \
# Model
# HistGradientBoostingRegressor                         0.47            1.00
# LGBMRegressor                                         0.46            1.00
# RandomForestRegressor                                 0.46            1.01
# NuSVR                                                 0.44            1.02
# BaggingRegressor                                      0.42            1.04
# MLPRegressor                                          0.42            1.04
# SVR                                                   0.42            1.05
# GradientBoostingRegressor                             0.41            1.05
# XGBRegressor                                          0.41            1.06
# Ridge                                                 0.38            1.08
# RidgeCV                                               0.38            1.08
# BayesianRidge                                         0.38            1.08
# KNeighborsRegressor                                   0.37            1.09
# ElasticNetCV                                          0.37            1.09
# LassoCV                                               0.37            1.09
# PoissonRegressor                                      0.37            1.09
# LassoLarsIC                                           0.36            1.10
# HuberRegressor                                        0.36            1.10
# LinearSVR                                             0.35            1.11
# SGDRegressor                                          0.35            1.11
# GammaRegressor                                        0.33            1.12
# GeneralizedLinearRegressor                            0.33            1.12
# TweedieRegressor                                      0.33            1.12
# LassoLarsCV                                           0.32            1.13
# OrthogonalMatchingPursuitCV                           0.32            1.13
# OrthogonalMatchingPursuit                             0.32            1.13
# ExtraTreesRegressor                                   0.29            1.15
# AdaBoostRegressor                                     0.27            1.17
# DecisionTreeRegressor                                 0.25            1.19
# ExtraTreeRegressor                                    0.20            1.23
# LarsCV                                                0.19            1.24
# PassiveAggressiveRegressor                            0.13            1.28
# ElasticNet                                            0.00            1.37
# Lasso                                                -0.00            1.37
# DummyRegressor                                       -0.00            1.37
# LassoLars                                            -0.00            1.37
# KernelRidge                                         -18.94            6.12
# GaussianProcessRegressor                          -7080.00          115.41
# Lars                                             -40315.49          275.39
# LinearRegression                  -15882079882172342272.00   5465829518.74
# TransformedTargetRegressor        -15882079882172342272.00   5465829518.74
# RANSACRegressor               -322871515287194030833664.00 779322580127.25
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor        3.73
# LGBMRegressor                        0.39
# RandomForestRegressor                2.87
# NuSVR                                1.16
# BaggingRegressor                     0.35
# MLPRegressor                         3.38
# SVR                                  1.40
# GradientBoostingRegressor            1.22
# XGBRegressor                         1.38
# Ridge                                0.06
# RidgeCV                              0.15
# BayesianRidge                        0.24
# KNeighborsRegressor                  0.40
# ElasticNetCV                         4.16
# LassoCV                              4.23
# PoissonRegressor                     0.09
# LassoLarsIC                          0.14
# HuberRegressor                       0.36
# LinearSVR                            0.59
# SGDRegressor                         0.13
# GammaRegressor                       0.06
# GeneralizedLinearRegressor           0.06
# TweedieRegressor                     0.06
# LassoLarsCV                          0.28
# OrthogonalMatchingPursuitCV          0.13
# OrthogonalMatchingPursuit            0.05
# ExtraTreesRegressor                  3.05
# AdaBoostRegressor                    0.52
# DecisionTreeRegressor                0.12
# ExtraTreeRegressor                   0.09
# LarsCV                               0.62
# PassiveAggressiveRegressor           0.07
# ElasticNet                           0.04
# Lasso                                0.07
# DummyRegressor                       0.03
# LassoLars                            0.11
# KernelRidge                          0.45
# GaussianProcessRegressor             1.41
# Lars                                 0.17
# LinearRegression                     0.12
# TransformedTargetRegressor           0.07
# RANSACRegressor                      1.29

# %%
# Performance table of many models on the testing datset (20%)
aromatase_test
# Out:
#                                         Adjusted R-Squared  \
# Model
# HistGradientBoostingRegressor                         0.27
# LGBMRegressor                                         0.26
# RandomForestRegressor                                 0.25
# NuSVR                                                 0.23
# BaggingRegressor                                      0.20
# MLPRegressor                                          0.20
# SVR                                                   0.20
# GradientBoostingRegressor                             0.19
# XGBRegressor                                          0.18
# Ridge                                                 0.15
# RidgeCV                                               0.15
# BayesianRidge                                         0.14
# KNeighborsRegressor                                   0.14
# ElasticNetCV                                          0.13
# LassoCV                                               0.13
# PoissonRegressor                                      0.13
# LassoLarsIC                                           0.12
# HuberRegressor                                        0.11
# LinearSVR                                             0.10
# SGDRegressor                                          0.10
# GammaRegressor                                        0.08
# GeneralizedLinearRegressor                            0.08
# TweedieRegressor                                      0.08
# LassoLarsCV                                           0.07
# OrthogonalMatchingPursuitCV                           0.06
# OrthogonalMatchingPursuit                             0.06
# ExtraTreesRegressor                                   0.02
# AdaBoostRegressor                                    -0.01
# DecisionTreeRegressor                                -0.04
# ExtraTreeRegressor                                   -0.10
# LarsCV                                               -0.12
# PassiveAggressiveRegressor                           -0.21
# ElasticNet                                           -0.38
# Lasso                                                -0.38
# DummyRegressor                                       -0.38
# LassoLars                                            -0.38
# KernelRidge                                         -26.51
# GaussianProcessRegressor                          -9770.09
# Lars                                             -55631.81
# LinearRegression                  -21915713170742718464.00
# TransformedTargetRegressor        -21915713170742718464.00
# RANSACRegressor               -445531037026201561464832.00
#
#                                                  R-Squared            RMSE  \
# Model
# HistGradientBoostingRegressor                         0.47            1.00
# LGBMRegressor                                         0.46            1.00
# RandomForestRegressor                                 0.46            1.01
# NuSVR                                                 0.44            1.02
# BaggingRegressor                                      0.42            1.04
# MLPRegressor                                          0.42            1.04
# SVR                                                   0.42            1.05
# GradientBoostingRegressor                             0.41            1.05
# XGBRegressor                                          0.41            1.06
# Ridge                                                 0.38            1.08
# RidgeCV                                               0.38            1.08
# BayesianRidge                                         0.38            1.08
# KNeighborsRegressor                                   0.37            1.09
# ElasticNetCV                                          0.37            1.09
# LassoCV                                               0.37            1.09
# PoissonRegressor                                      0.37            1.09
# LassoLarsIC                                           0.36            1.10
# HuberRegressor                                        0.36            1.10
# LinearSVR                                             0.35            1.11
# SGDRegressor                                          0.35            1.11
# GammaRegressor                                        0.33            1.12
# GeneralizedLinearRegressor                            0.33            1.12
# TweedieRegressor                                      0.33            1.12
# LassoLarsCV                                           0.32            1.13
# OrthogonalMatchingPursuitCV                           0.32            1.13
# OrthogonalMatchingPursuit                             0.32            1.13
# ExtraTreesRegressor                                   0.29            1.15
# AdaBoostRegressor                                     0.27            1.17
# DecisionTreeRegressor                                 0.25            1.19
# ExtraTreeRegressor                                    0.20            1.23
# LarsCV                                                0.19            1.24
# PassiveAggressiveRegressor                            0.13            1.28
# ElasticNet                                            0.00            1.37
# Lasso                                                -0.00            1.37
# DummyRegressor                                       -0.00            1.37
# LassoLars                                            -0.00            1.37
# KernelRidge                                         -18.94            6.12
# GaussianProcessRegressor                          -7080.00          115.41
# Lars                                             -40315.49          275.39
# LinearRegression                  -15882079882172342272.00   5465829518.74
# TransformedTargetRegressor        -15882079882172342272.00   5465829518.74
# RANSACRegressor               -322871515287194030833664.00 779322580127.25
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor        3.73
# LGBMRegressor                        0.39
# RandomForestRegressor                2.87
# NuSVR                                1.16
# BaggingRegressor                     0.35
# MLPRegressor                         3.38
# SVR                                  1.40
# GradientBoostingRegressor            1.22
# XGBRegressor                         1.38
# Ridge                                0.06
# RidgeCV                              0.15
# BayesianRidge                        0.24
# KNeighborsRegressor                  0.40
# ElasticNetCV                         4.16
# LassoCV                              4.23
# PoissonRegressor                     0.09
# LassoLarsIC                          0.14
# HuberRegressor                       0.36
# LinearSVR                            0.59
# SGDRegressor                         0.13
# GammaRegressor                       0.06
# GeneralizedLinearRegressor           0.06
# TweedieRegressor                     0.06
# LassoLarsCV                          0.28
# OrthogonalMatchingPursuitCV          0.13
# OrthogonalMatchingPursuit            0.05
# ExtraTreesRegressor                  3.05
# AdaBoostRegressor                    0.52
# DecisionTreeRegressor                0.12
# ExtraTreeRegressor                   0.09
# LarsCV                               0.62
# PassiveAggressiveRegressor           0.07
# ElasticNet                           0.04
# Lasso                                0.07
# DummyRegressor                       0.03
# LassoLars                            0.11
# KernelRidge                          0.45
# GaussianProcessRegressor             1.41
# Lars                                 0.17
# LinearRegression                     0.12
# TransformedTargetRegressor           0.07
# RANSACRegressor                      1.29

# %% [markdown]
# ## Data Visualization and Model Performance

# %% [markdown]
# ### R_squared Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=aromatase_train.index, x="R-Squared", data=aromatase_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %% [markdown]
# ### RSME Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=aromatase_train.index, x="RMSE", data=aromatase_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %% [markdown]
# ### Calculation Times

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=aromatase_train.index, x="Time Taken", data=aromatase_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
